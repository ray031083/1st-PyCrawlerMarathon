# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://www.ptt.cc/bbs/NBA/index.html'
url_firstP = 'https://www.ptt.cc/bbs/NBA/index1.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")
columns = ['作者', '看板', '標題', '時間']

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
items = soup.findAll(True, {"class": re.compile(r'(r-ent|r-list-sep)')})
for item in range(len(items)):
    if 'r-list-sep' in items[item].attrs['class']:
        try:
            r = BeautifulSoup(requests.get('https://www.ptt.cc'+items[item-1].a['href']).text, "html5lib")
            article = []
            for info in r.find_all(class_='article-meta-value'):
                article.append(info.text)
            print('作者: {}\n標題: {}\n時間: {}'.format(article[0], article[2], article[-1]))
        except:
            continue
# Out:
# 作者: rfvtgb (........)
# 標題: Re: [討論] 2020 NBA歷史百大球員排行
# 時間: Tue Oct 13 19:39:11 2020

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
def GetFistInfo(url):
    r = requests.get(url)
    
    soup = BeautifulSoup(r.text, "html5lib")
    
    articles = []
    
    for d in soup.find_all(class_="title"):
        try:
            r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
            article = []
            for info in r.find_all(class_='article-meta-value'):
                article.append(info.text)
            articles.append(article)
        except:
            continue
    df = pd.DataFrame(articles, columns=columns)
    
    return df

# %%
GetFistInfo(url_firstP)
# Out:
#                              作者   看板                         標題  \
# 0                 Price (Price)  NBA    [轉錄]Lyotard 對於太陽板討論串的結論
# 1                 Price (Price)  NBA        [公告] 請停止一切關於本次活動的發言
# 2               Frankaze (神采風華)  NBA   [轉錄]跟之前那篇比起來 我覺得這篇也應該轉過來
# 3               Frankaze (神采風華)  NBA                [轉錄]再轉一篇好文來
# 4                 Price (Price)  NBA           [轉錄][情報] 夏洛特山貓系列
# 5                 Price (Price)  NBA   [轉錄]Re: [心得] 真是受不了糗爺....
# 6                 Price (Price)  NBA            [轉錄]總冠軍賽NO.2觀後感
# 7   AmuroNamie (原來太嗨真的會失眠^___^)  NBA       [心得] Rasheed Wallace
# 8                  toptree (  )  NBA                    掌控球賽的男人
# 9            skchang (3EB板開板囉！)  NBA        [閒聊] 說說2004季後賽名場面回顧
# 10                   shineup ()  NBA     [心得] 其實說穿了 就是活塞的防守太可怕了
# 11                    cOvi (喵~)  NBA    Re: [閒聊] 說說2004季後賽名場面回顧
# 12               ykshih (￼N￼Ns)  NBA    Re: [閒聊] 說說2004季後賽名場面回顧
# 13              Frankaze (神采風華)  NBA    Re: [閒聊] 說說2004季後賽名場面回顧
# 14                Price (Price)  NBA        [轉錄]Re: 總冠軍賽NO.3觀後感
# 15              Frankaze (神采風華)  NBA        [轉錄]Re: 總冠軍賽NO.3觀後感
# 16          star1 (第一次魔術表演不算成功)  NBA    Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# 17              coldspring (笑笑)  NBA    Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# 18                 airbear (地圖)  NBA  Re: Kobe is frustrated...
# 19            pennykidd (andre)  NBA    Re: [轉錄]Re: 總冠軍賽NO.3觀後感
#
#                           時間
# 0   Sun May 16 01:54:33 2004
# 1   Mon May 24 00:43:00 2004
# 2   Tue Jun  8 01:16:45 2004
# 3   Tue Jun  8 09:02:23 2004
# 4   Thu Jun 10 00:39:35 2004
# 5   Thu Jun 10 00:51:35 2004
# 6   Thu Jun 10 12:05:07 2004
# 7   Fri Jun 11 15:06:09 2004
# 8   Sat Jun 12 07:13:04 2004
# 9   Sat Jun 12 13:21:49 2004
# 10  Sat Jun 12 13:12:47 2004
# 11  Sat Jun 12 16:43:07 2004
# 12  Sat Jun 12 17:26:37 2004
# 13  Sat Jun 12 18:34:46 2004
# 14  Mon Jun 14 02:18:52 2004
# 15  Mon Jun 14 02:34:33 2004
# 16  Mon Jun 14 07:16:30 2004
# 17  Mon Jun 14 09:24:57 2004
# 18  Mon Jun 14 12:56:14 2004
# 19  Mon Jun 14 22:07:01 2004

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
GetFistInfo('https://www.ptt.cc/bbs/Stock/index.html')
# Out:
#                                作者     看板                            標題  \
# 0     samuel655200 (samuel655200)  Stock     Re: [請益] 存股族最終會失敗被洗出去的原因？
# 1              ericerix (我的帥，在於臉)  Stock                [其他] 零股賣兩天賣不出去
# 2         coconing (證 ㄓㄥˋ 券 ㄑㄩㄢˋ)  Stock   [其他] 109年10月13日 三大法人買賣金額統計表
# 3                 dash0804 (Dash)  Stock     [新聞] 台灣光罩買聯電2萬張 潛在利益倍增逾3億
# 4   Westbrook (Russell Westbrook)  Stock  [新聞] 中鋼11月內銷盤價連5漲 漲幅擴大至5.02％
# 5                rickywu8106 (阿齊)  Stock           [標的]4119旭富 股價委屈的股票!
# 6                   Hazer (Hazer)  Stock              [新聞] 東洋澄清：並非陸資企業
# 7                  scum5566 (你好宅)  Stock      [新聞] 首批水下基樁完工 沃旭：全力扶持在地供
# 8                laptic (靜夜聖林彼岸花)  Stock      [新聞] 金管會查獲大同違法中資 開罰2500萬
# 9                f204137 (Change)  Stock   [新聞] TDR大解禁！11檔被處置 僅杜康繼續延長撮
# 10                yoseii (yoseii)  Stock       [新聞] 美德醫 Q3 獲利大增 1150 倍
# 11                Lawleit (大員郭奉孝)  Stock             [標的] 3008大立光 鄧不利多
# 12          CavendishJr (真禮梅西姐姐♡)  Stock     [新聞] 高端疫苗搶頭香 獲疾管署4.7億元臨床補
# 13                  lichuer (Z揪兒)  Stock             [請益] 2303 聯電 長期投資
# 14        peterlin495 (專業果粉O'_'O)  Stock  [新聞] 要搶要快！發表會iPhone 12來勢洶洶 蘋
# 15                  Kobe5210 (旅程)  Stock     Re: [請益] 存股族最終會失敗被洗出去的原因？
# 16                           None   None                          None
# 17             yoche2000 (九龍塘麵包粉)  Stock       [情報] 十月除權息法說會行事曆 (每日更新)
# 18                  IanLi (IanLi)  Stock                 [公告] 精華區導覽Q&A
# 19       housemance (艾倫戴爾皇家空軍總司令)  Stock          [閒聊] 2020/10/13 盤後閒聊
#
#                           時間
# 0   Tue Oct 13 14:31:11 2020
# 1   Tue Oct 13 14:46:59 2020
# 2   Tue Oct 13 14:56:59 2020
# 3   Tue Oct 13 15:03:07 2020
# 4   Tue Oct 13 15:16:21 2020
# 5   Tue Oct 13 15:16:50 2020
# 6   Tue Oct 13 16:19:31 2020
# 7   Tue Oct 13 16:53:02 2020
# 8   Tue Oct 13 18:02:49 2020
# 9   Tue Oct 13 19:16:16 2020
# 10  Tue Oct 13 19:19:15 2020
# 11  Tue Oct 13 19:44:36 2020
# 12  Tue Oct 13 19:50:07 2020
# 13  Tue Oct 13 20:00:40 2020
# 14  Tue Oct 13 20:03:42 2020
# 15  Tue Oct 13 20:24:28 2020
# 16                      None
# 17  Sun Oct  4 23:49:42 2020
# 18  Sun Jan 25 23:18:20 2015
# 19  Tue Oct 13 14:01:06 2020
