# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('http://api.github.com/events')
r.text
# Out:
# '[{"id":"12450677246","type":"IssuesEvent","actor":{"id":34372510,"login":"Djennez","display_login":"Djennez","gravatar_id":"","url":"https://api.github.com/users/Djennez","avatar_url":"https://avatars.githubusercontent.com/u/34372510?"},"repo":{"id":52303337,"name":"Yoast/yoastseo-amp","url":"https://api.github.com/repos/Yoast/yoastseo-amp"},"payload":{"action":"closed","issue":{"url":"https://api.github.com/repos/Yoast/yoastseo-amp/issues/44","repository_url":"https://api.github.com/repos/Yoast/yoastseo-amp","labels_url":"https://api.github.com/repos/Yoast/yoastseo-amp/issues/44/labels{/name}","comments_url":"https://api.github.com/repos/Yoast/yoastseo-amp/issues/44/comments","events_url":"https://api.github.com/repos/Yoast/yoastseo-amp/issues/44/events","html_url":"https://github.com/Yoast/yoastseo-amp/issues/44","id":189189663,"node_id":"MDU6SXNzdWUxODkxODk2NjM=","number":44,"title":"Header Color, Text Color, Post MetaColor fail to display as expected","user":{"login":"Pcosta88","id":8238074,"node_id":"MDQ6VXNlcjgyMzgwNzQ=","avatar_url":"https://avatars3.githubusercontent.com/u/8238074?v=4","gravatar_id":"","url":"https://api.github.com/users/Pcosta88","html_url":"https://github.com/Pcosta88","followers_url":"https://api.github.com/users/Pcosta88/followers","following_url":"https://api.github.com/users/Pcosta88/following{/other_user}","gists_url":"https://api.github.com/users/Pcosta88/gists{/gist_id}","starred_url":"https://api.github.com/users/Pcosta88/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/Pcosta88/subscriptions","organizations_url":"https://api.github.com/users/Pcosta88/orgs","repos_url":"https://api.github.com/users/Pcosta88/repos","events_url":"https://api.github.com/users/Pcosta88/events{/privacy}","received_events_url":"https://api.github.com/users/Pcosta88/received_events","type":"User","site_admin":false},"labels":[{"id":382916228,"node_id":"MDU6TGFiZWwzODI5MTYyMjg=","url":"https://api.github.com/repos/Yoast/yoastseo-amp/labels/support","name":"support","color":"ededed","default":false,"description":null}],"state":"closed","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":4,"created_at":"2016-11-14T18:34:27Z","updated_at":"2020-05-27T09:11:32Z","closed_at":"2020-05-27T09:11:32Z","author_association":"NONE","body":"### What did you expect to happen?\\r\\nWhen colors were selected for Header, Text, and PostMeta they would display.\\r\\n### What happened instead?\\r\\nThe colors did not change. \\r\\n### How can we reproduce this behavior?\\r\\n**1.Create Post**\\r\\n\\r\\n**2.Add Colors in the Glue Plugin**\\r\\n\\r\\n![screen shot 2016-11-14 at 1 33 10 pm](https://cloud.githubusercontent.com/assets/8238074/20277552/073da91a-aa6f-11e6-8371-8da84c8a0eff.png)\\r\\n\\r\\n\\r\\n**3.See them fail to change**\\r\\n\\r\\n![screen_shot_2016-11-14_at_1_33_25_pm](https://cloud.githubusercontent.com/assets/8238074/20277556/0ad68380-aa6f-11e6-866e-738f83b27534.png)\\r\\n\\r\\n\\r\\n### Technical info\\r\\n* WordPress version: 4.6.1\\r\\n* Yoast SEO version: 3.8\\r\\n* Yoast SEO Glue version: 0.3.3\\r\\n* AMP plugin version: 0.4.2\\r\\n"}},"public":true,"created_at":"2020-05-27T09:11:32Z","org":{"id":4690436,"login":"Yoast","gravatar_id":"","url":"https://api.github.com/orgs/Yoast","avatar_url":"https://avatars.githubusercontent.com/u/4690436?"}},{"id":"12450677227","type":"PushEvent","actor":{"id":63000763,"login":"Junhan0037","display_login":"Junhan0037","gravatar_id":"","url":"https://api.github.com/users/Junhan0037","avatar_url":"https://avatars.githubusercontent.com/u/63000763?"},"repo":{"id":267271907,"name":"Junhan0037/react-movie_app_2020","url":"https://api.github.com/repos/Junhan0037/react-movie_app_2020"},"payload":{"push_id":5134550354,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"894fa66cf5dc9b9217cedb8f234ec4d60c7c07cf","before":"338d65cd9d2a5b8eef6a3a2f941b279807d7e98f","commits":[{"sha":"894fa66cf5dc9b9217cedb8f234ec4d60c7c07cf","author":{" ...

# %%
import json
json.loads(r.text)
# Out:
# [{'id': '12450677246',
#   'type': 'IssuesEvent',
#   'actor': {'id': 34372510,
#    'login': 'Djennez',
#    'display_login': 'Djennez',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Djennez',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34372510?'},
#   'repo': {'id': 52303337,
#    'name': 'Yoast/yoastseo-amp',
#    'url': 'https://api.github.com/repos/Yoast/yoastseo-amp'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/Yoast/yoastseo-amp/issues/44',
#     'repository_url': 'https://api.github.com/repos/Yoast/yoastseo-amp',
#     'labels_url': 'https://api.github.com/repos/Yoast/yoastseo-amp/issues/44/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Yoast/yoastseo-amp/issues/44/comments',
#     'events_url': 'https://api.github.com/repos/Yoast/yoastseo-amp/issues/44/events',
#     'html_url': 'https://github.com/Yoast/yoastseo-amp/issues/44',
#     'id': 189189663,
#     'node_id': 'MDU6SXNzdWUxODkxODk2NjM=',
#     'number': 44,
#     'title': 'Header Color, Text Color, Post MetaColor fail to display as expected',
#     'user': {'login': 'Pcosta88',
#      'id': 8238074,
#      'node_id': 'MDQ6VXNlcjgyMzgwNzQ=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/8238074?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Pcosta88',
#      'html_url': 'https://github.com/Pcosta88',
#      'followers_url': 'https://api.github.com/users/Pcosta88/followers',
#      'following_url': 'https://api.github.com/users/Pcosta88/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Pcosta88/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Pcosta88/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Pcosta88/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Pcosta88/orgs',
#      'repos_url': 'https://api.github.com/users/Pcosta88/repos',
#      'events_url': 'https://api.github.com/users/Pcosta88/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Pcosta88/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 382916228,
#       'node_id': 'MDU6TGFiZWwzODI5MTYyMjg=',
#       'url': 'https://api.github.com/repos/Yoast/yoastseo-amp/labels/support',
#       'name': 'support',
#       'color': 'ededed',
#       'default': False,
#       'description': None}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 4,
#     'created_at': '2016-11-14T18:34:27Z',
#     'updated_at': '2020-05-27T09:11:32Z',
#     'closed_at': '2020-05-27T09:11:32Z',
#     'author_association': 'NONE',
#     'body': '### What did you expect to happen?\r\nWhen colors were selected for Header, Text, and PostMeta they would display.\r\n### What happened instead?\r\nThe colors did not change. \r\n### How can we reproduce this behavior?\r\n**1.Create Post**\r\n\r\n**2.Add Colors in the Glue Plugin**\r\n\r\n![screen shot 2016-11-14 at 1 33 10 pm](https://cloud.githubusercontent.com/assets/8238074/20277552/073da91a-aa6f-11e6-8371-8da84c8a0eff.png)\r\n\r\n\r\n**3.See them fail to change**\r\n\r\n![screen_shot_2016-11-14_at_1_33_25_pm](https://cloud.githubusercontent.com/assets/8238074/20277556/0ad68380-aa6f-11e6-866e-738f83b27534.png)\r\n\r\n\r\n### Technical info\r\n* WordPress version: 4.6.1\r\n* Yoast SEO version: 3.8\r\n* Yoast SEO Glue version: 0.3.3\r\n* AMP plugin version: 0.4.2\r\n'}},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z',
#   'org': {'id': 4690436,
#    'login': 'Yoast',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Yoast',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4690436?'}},
#  {'id': '12450677227',
#   'type': 'PushEvent',
#   'actor': {'id': 63000763,
#    'login': 'Junhan0037',
#    'display_login': 'Junhan0037',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Junhan0037',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63000763?'},
#   'repo': {'id': 267271907,
#    'name': 'Junhan0037/react-movie_app_2020',
#    'url': 'https://api.github.com/repos/Junhan0037/react-movie_app_2020'},
#   'payload': {'push_id': 5134550354,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '894fa66cf5dc9b9217cedb8f234ec4d60c7c07cf',
#    'before': '338d65cd9d2a5b8eef6a3a2f941b279807d7e98f',
#    'commits': [{'sha': '894fa66cf5dc9b9217cedb8f234ec4d60c7c07cf',
#      'author': {'email': 'wnsgks0037@naver.com', 'name': 'Junhan0037'},
#      'message': 'edit file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Junhan0037/react-movie_app_2020/commits/894fa66cf5dc9b9217cedb8f234ec4d60c7c07cf'}]},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677223',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 39814207,
#    'login': 'pull[bot]',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#   'repo': {'id': 189263618,
#    'name': 'michal-hudy/cli',
#    'url': 'https://api.github.com/repos/michal-hudy/cli'},
#   'payload': {'action': 'opened',
#    'number': 126,
#    'pull_request': {'url': 'https://api.github.com/repos/michal-hudy/cli/pulls/126',
#     'id': 423716264,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDIzNzE2MjY0',
#     'html_url': 'https://github.com/michal-hudy/cli/pull/126',
#     'diff_url': 'https://github.com/michal-hudy/cli/pull/126.diff',
#     'patch_url': 'https://github.com/michal-hudy/cli/pull/126.patch',
#     'issue_url': 'https://api.github.com/repos/michal-hudy/cli/issues/126',
#     'number': 126,
#     'state': 'open',
#     'locked': False,
#     'title': '[pull] master from kyma-project:master',
#     'user': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'See Commits and Changes for more details.\n\n-----\nCreated by [<img src="https://prod.download/pull-18h-svg" valign="bottom"/> **pull[bot]**](https://github.com/wei/pull). Want to support this open source service? [Please star it : )](https://github.com/wei/pull)',
#     'created_at': '2020-05-27T09:11:32Z',
#     'updated_at': '2020-05-27T09:11:32Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/michal-hudy/cli/pulls/126/commits',
#     'review_comments_url': 'https://api.github.com/repos/michal-hudy/cli/pulls/126/comments',
#     'review_comment_url': 'https://api.github.com/repos/michal-hudy/cli/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/michal-hudy/cli/issues/126/comments',
#     'statuses_url': 'https://api.github.com/repos/michal-hudy/cli/statuses/63288b64f860879dd2c1000bca1c997e0caae6b2',
#     'head': {'label': 'kyma-project:master',
#      'ref': 'master',
#      'sha': '63288b64f860879dd2c1000bca1c997e0caae6b2',
#      'user': {'login': 'kyma-project',
#       'id': 39153523,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM5MTUzNTIz',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/39153523?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kyma-project',
#       'html_url': 'https://github.com/kyma-project',
#       'followers_url': 'https://api.github.com/users/kyma-project/followers',
#       'following_url': 'https://api.github.com/users/kyma-project/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kyma-project/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kyma-project/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kyma-project/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kyma-project/orgs',
#       'repos_url': 'https://api.github.com/users/kyma-project/repos',
#       'events_url': 'https://api.github.com/users/kyma-project/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kyma-project/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 157188288,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNTcxODgyODg=',
#       'name': 'cli',
#       'full_name': 'kyma-project/cli',
#       'private': False,
#       'owner': {'login': 'kyma-project',
#        'id': 39153523,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM5MTUzNTIz',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/39153523?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/kyma-project',
#        'html_url': 'https://github.com/kyma-project',
#        'followers_url': 'https://api.github.com/users/kyma-project/followers',
#        'following_url': 'https://api.github.com/users/kyma-project/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/kyma-project/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/kyma-project/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/kyma-project/subscriptions',
#        'organizations_url': 'https://api.github.com/users/kyma-project/orgs',
#        'repos_url': 'https://api.github.com/users/kyma-project/repos',
#        'events_url': 'https://api.github.com/users/kyma-project/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/kyma-project/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/kyma-project/cli',
#       'description': 'Simple set of commands to manage a Kyma installation',
#       'fork': False,
#       'url': 'https://api.github.com/repos/kyma-project/cli',
#       'forks_url': 'https://api.github.com/repos/kyma-project/cli/forks',
#       'keys_url': 'https://api.github.com/repos/kyma-project/cli/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/kyma-project/cli/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/kyma-project/cli/teams',
#       'hooks_url': 'https://api.github.com/repos/kyma-project/cli/hooks',
#       'issue_events_url': 'https://api.github.com/repos/kyma-project/cli/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/kyma-project/cli/events',
#       'assignees_url': 'https://api.github.com/repos/kyma-project/cli/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/kyma-project/cli/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/kyma-project/cli/tags',
#       'blobs_url': 'https://api.github.com/repos/kyma-project/cli/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/kyma-project/cli/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/kyma-project/cli/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/kyma-project/cli/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/kyma-project/cli/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/kyma-project/cli/languages',
#       'stargazers_url': 'https://api.github.com/repos/kyma-project/cli/stargazers',
#       'contributors_url': 'https://api.github.com/repos/kyma-project/cli/contributors',
#       'subscribers_url': 'https://api.github.com/repos/kyma-project/cli/subscribers',
#       'subscription_url': 'https://api.github.com/repos/kyma-project/cli/subscription',
#       'commits_url': 'https://api.github.com/repos/kyma-project/cli/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/kyma-project/cli/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/kyma-project/cli/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/kyma-project/cli/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/kyma-project/cli/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/kyma-project/cli/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/kyma-project/cli/merges',
#       'archive_url': 'https://api.github.com/repos/kyma-project/cli/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/kyma-project/cli/downloads',
#       'issues_url': 'https://api.github.com/repos/kyma-project/cli/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/kyma-project/cli/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/kyma-project/cli/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/kyma-project/cli/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/kyma-project/cli/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/kyma-project/cli/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/kyma-project/cli/deployments',
#       'created_at': '2018-11-12T09:28:32Z',
#       'updated_at': '2020-05-27T08:13:03Z',
#       'pushed_at': '2020-05-27T08:13:01Z',
#       'git_url': 'git://github.com/kyma-project/cli.git',
#       'ssh_url': 'git@github.com:kyma-project/cli.git',
#       'clone_url': 'https://github.com/kyma-project/cli.git',
#       'svn_url': 'https://github.com/kyma-project/cli',
#       'homepage': '',
#       'size': 853,
#       'stargazers_count': 50,
#       'watchers_count': 50,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 51,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 32,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 51,
#       'open_issues': 32,
#       'watchers': 50,
#       'default_branch': 'master'}},
#     'base': {'label': 'michal-hudy:master',
#      'ref': 'master',
#      'sha': '186cc96d169136a3da8cc335d63379fd580424e4',
#      'user': {'login': 'michal-hudy',
#       'id': 26445970,
#       'node_id': 'MDQ6VXNlcjI2NDQ1OTcw',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/26445970?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/michal-hudy',
#       'html_url': 'https://github.com/michal-hudy',
#       'followers_url': 'https://api.github.com/users/michal-hudy/followers',
#       'following_url': 'https://api.github.com/users/michal-hudy/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/michal-hudy/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/michal-hudy/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/michal-hudy/subscriptions',
#       'organizations_url': 'https://api.github.com/users/michal-hudy/orgs',
#       'repos_url': 'https://api.github.com/users/michal-hudy/repos',
#       'events_url': 'https://api.github.com/users/michal-hudy/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/michal-hudy/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 189263618,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODkyNjM2MTg=',
#       'name': 'cli',
#       'full_name': 'michal-hudy/cli',
#       'private': False,
#       'owner': {'login': 'michal-hudy',
#        'id': 26445970,
#        'node_id': 'MDQ6VXNlcjI2NDQ1OTcw',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/26445970?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/michal-hudy',
#        'html_url': 'https://github.com/michal-hudy',
#        'followers_url': 'https://api.github.com/users/michal-hudy/followers',
#        'following_url': 'https://api.github.com/users/michal-hudy/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/michal-hudy/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/michal-hudy/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/michal-hudy/subscriptions',
#        'organizations_url': 'https://api.github.com/users/michal-hudy/orgs',
#        'repos_url': 'https://api.github.com/users/michal-hudy/repos',
#        'events_url': 'https://api.github.com/users/michal-hudy/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/michal-hudy/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/michal-hudy/cli',
#       'description': 'Simple set of commands to manage a Kyma installation',
#       'fork': True,
#       'url': 'https://api.github.com/repos/michal-hudy/cli',
#       'forks_url': 'https://api.github.com/repos/michal-hudy/cli/forks',
#       'keys_url': 'https://api.github.com/repos/michal-hudy/cli/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/michal-hudy/cli/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/michal-hudy/cli/teams',
#       'hooks_url': 'https://api.github.com/repos/michal-hudy/cli/hooks',
#       'issue_events_url': 'https://api.github.com/repos/michal-hudy/cli/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/michal-hudy/cli/events',
#       'assignees_url': 'https://api.github.com/repos/michal-hudy/cli/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/michal-hudy/cli/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/michal-hudy/cli/tags',
#       'blobs_url': 'https://api.github.com/repos/michal-hudy/cli/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/michal-hudy/cli/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/michal-hudy/cli/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/michal-hudy/cli/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/michal-hudy/cli/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/michal-hudy/cli/languages',
#       'stargazers_url': 'https://api.github.com/repos/michal-hudy/cli/stargazers',
#       'contributors_url': 'https://api.github.com/repos/michal-hudy/cli/contributors',
#       'subscribers_url': 'https://api.github.com/repos/michal-hudy/cli/subscribers',
#       'subscription_url': 'https://api.github.com/repos/michal-hudy/cli/subscription',
#       'commits_url': 'https://api.github.com/repos/michal-hudy/cli/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/michal-hudy/cli/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/michal-hudy/cli/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/michal-hudy/cli/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/michal-hudy/cli/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/michal-hudy/cli/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/michal-hudy/cli/merges',
#       'archive_url': 'https://api.github.com/repos/michal-hudy/cli/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/michal-hudy/cli/downloads',
#       'issues_url': 'https://api.github.com/repos/michal-hudy/cli/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/michal-hudy/cli/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/michal-hudy/cli/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/michal-hudy/cli/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/michal-hudy/cli/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/michal-hudy/cli/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/michal-hudy/cli/deployments',
#       'created_at': '2019-05-29T16:44:01Z',
#       'updated_at': '2020-05-26T13:11:38Z',
#       'pushed_at': '2020-05-26T13:11:36Z',
#       'git_url': 'git://github.com/michal-hudy/cli.git',
#       'ssh_url': 'git@github.com:michal-hudy/cli.git',
#       'clone_url': 'https://github.com/michal-hudy/cli.git',
#       'svn_url': 'https://github.com/michal-hudy/cli',
#       'homepage': '',
#       'size': 808,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Go',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/michal-hudy/cli/pulls/126'},
#      'html': {'href': 'https://github.com/michal-hudy/cli/pull/126'},
#      'issue': {'href': 'https://api.github.com/repos/michal-hudy/cli/issues/126'},
#      'comments': {'href': 'https://api.github.com/repos/michal-hudy/cli/issues/126/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/michal-hudy/cli/pulls/126/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/michal-hudy/cli/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/michal-hudy/cli/pulls/126/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/michal-hudy/cli/statuses/63288b64f860879dd2c1000bca1c997e0caae6b2'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 8,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677234',
#   'type': 'DeleteEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 265252322,
#    'name': 'brunoalvesdefaria/custom-login',
#    'url': 'https://api.github.com/repos/brunoalvesdefaria/custom-login'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/terser-webpack-plugin-3.0.1',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677236',
#   'type': 'CreateEvent',
#   'actor': {'id': 28305181,
#    'login': 'jeremie-gauthier',
#    'display_login': 'jeremie-gauthier',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jeremie-gauthier',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28305181?'},
#   'repo': {'id': 267267576,
#    'name': 'jeremie-gauthier/jeremie-gauthier.github.io',
#    'url': 'https://api.github.com/repos/jeremie-gauthier/jeremie-gauthier.github.io'},
#   'payload': {'ref': 'gh-pages',
#    'ref_type': 'branch',
#    'master_branch': 'gh-pages',
#    'description': 'My portfolio',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677219',
#   'type': 'DeleteEvent',
#   'actor': {'id': 42873674,
#    'login': 'CircleJanewayTest',
#    'display_login': 'CircleJanewayTest',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CircleJanewayTest',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42873674?'},
#   'repo': {'id': 164702370,
#    'name': 'CircleCITestOrg/smoke-test-test-repo',
#    'url': 'https://api.github.com/repos/CircleCITestOrg/smoke-test-test-repo'},
#   'payload': {'ref': 'build-artifacts-2020-05-27T09-11-10',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z',
#   'org': {'id': 32499712,
#    'login': 'CircleCITestOrg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/CircleCITestOrg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32499712?'}},
#  {'id': '12450677217',
#   'type': 'WatchEvent',
#   'actor': {'id': 64124057,
#    'login': 'llyhong',
#    'display_login': 'llyhong',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/llyhong',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64124057?'},
#   'repo': {'id': 83315270,
#    'name': 'mob-sakai/UIEffect',
#    'url': 'https://api.github.com/repos/mob-sakai/UIEffect'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677201',
#   'type': 'PushEvent',
#   'actor': {'id': 54973413,
#    'login': 'Royalatomo',
#    'display_login': 'Royalatomo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Royalatomo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54973413?'},
#   'repo': {'id': 267268490,
#    'name': 'Royalatomo/HostScanner',
#    'url': 'https://api.github.com/repos/Royalatomo/HostScanner'},
#   'payload': {'push_id': 5134550336,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '505415ed2f46004513c10b88ef59041c8af58c3b',
#    'before': 'dc3a090d5ba3bfe81edcc8d270a7165c0aa171f8',
#    'commits': [{'sha': '505415ed2f46004513c10b88ef59041c8af58c3b',
#      'author': {'email': 'bingo@example.com', 'name': 'bingo'},
#      'message': 'The Acutual Scanner File',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Royalatomo/HostScanner/commits/505415ed2f46004513c10b88ef59041c8af58c3b'}]},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677200',
#   'type': 'PushEvent',
#   'actor': {'id': 56597318,
#    'login': 'shenshen0318',
#    'display_login': 'shenshen0318',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shenshen0318',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56597318?'},
#   'repo': {'id': 267269041,
#    'name': 'shenshen0318/hahaha.github.io',
#    'url': 'https://api.github.com/repos/shenshen0318/hahaha.github.io'},
#   'payload': {'push_id': 5134550335,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '649bc835caee2a9a70f940e87b52d6e2e73137e1',
#    'before': '4dad132d572f633d488022179395284168ac6b65',
#    'commits': [{'sha': '649bc835caee2a9a70f940e87b52d6e2e73137e1',
#      'author': {'email': '56597318+shenshen0318@users.noreply.github.com',
#       'name': 'Shen'},
#      'message': 'Update _config.yml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shenshen0318/hahaha.github.io/commits/649bc835caee2a9a70f940e87b52d6e2e73137e1'}]},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677182',
#   'type': 'PushEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 215110795,
#    'name': 'hiramatsutaku/blog.hirataku.dev',
#    'url': 'https://api.github.com/repos/hiramatsutaku/blog.hirataku.dev'},
#   'payload': {'push_id': 5134550325,
#    'size': 3,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dependabot/npm_and_yarn/stylelint-13.5.0',
#    'head': '4ff2145f6040f0e18b64c6d62116b4cde272c603',
#    'before': '966468216beaf455f40200f80218aeae9c5b09e1',
#    'commits': [{'sha': '0d867a4819833df8bb9849eadd245c73b4257ded',
#      'author': {'email': '27856297+dependabot-preview[bot]@users.noreply.github.com',
#       'name': 'dependabot-preview[bot]'},
#      'message': 'Bump @storybook/addon-storyshots from 5.3.18 to 5.3.19\n\nBumps [@storybook/addon-storyshots](https://github.com/storybookjs/storybook/tree/HEAD/addons/storyshots/storyshots-core) from 5.3.18 to 5.3.19.\n- [Release notes](https://github.com/storybookjs/storybook/releases)\n- [Changelog](https://github.com/storybookjs/storybook/blob/next/CHANGELOG.md)\n- [Commits](https://github.com/storybookjs/storybook/commits/v5.3.19/addons/storyshots/storyshots-core)\n\nSigned-off-by: dependabot-preview[bot] <support@dependabot.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/hiramatsutaku/blog.hirataku.dev/commits/0d867a4819833df8bb9849eadd245c73b4257ded'},
#     {'sha': '102123dece164fa087861deb0f6c041c921a72b1',
#      'author': {'email': '27856297+dependabot-preview[bot]@users.noreply.github.com',
#       'name': 'dependabot-preview[bot]'},
#      'message': 'Merge pull request #349 from hiramatsutaku/dependabot/npm_and_yarn/storybook/addon-storyshots-5.3.19',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/hiramatsutaku/blog.hirataku.dev/commits/102123dece164fa087861deb0f6c041c921a72b1'},
#     {'sha': '4ff2145f6040f0e18b64c6d62116b4cde272c603',
#      'author': {'email': '27856297+dependabot-preview[bot]@users.noreply.github.com',
#       'name': 'dependabot-preview[bot]'},
#      'message': 'Bump stylelint from 13.3.3 to 13.5.0\n\nBumps [stylelint](https://github.com/stylelint/stylelint) from 13.3.3 to 13.5.0.\n- [Release notes](https://github.com/stylelint/stylelint/releases)\n- [Changelog](https://github.com/stylelint/stylelint/blob/master/CHANGELOG.md)\n- [Commits](https://github.com/stylelint/stylelint/compare/13.3.3...13.5.0)\n\nSigned-off-by: dependabot-preview[bot] <support@dependabot.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hiramatsutaku/blog.hirataku.dev/commits/4ff2145f6040f0e18b64c6d62116b4cde272c603'}]},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677171',
#   'type': 'WatchEvent',
#   'actor': {'id': 5821408,
#    'login': 'sfeuga',
#    'display_login': 'sfeuga',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sfeuga',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5821408?'},
#   'repo': {'id': 15508456,
#    'name': 'nutti/Magic-UV',
#    'url': 'https://api.github.com/repos/nutti/Magic-UV'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677157',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 49138417,
#    'name': 'Lombiq/Om.Orchard.SocialMetaTags',
#    'url': 'https://api.github.com/repos/Lombiq/Om.Orchard.SocialMetaTags'},
#   'payload': {'push_id': 5134550314,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/Orchard.1.8.Version',
#    'head': '050cc05bb54149bd6e18bf354b284e2831e6dc88',
#    'before': '050cc05bb54149bd6e18bf354b284e2831e6dc88',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '12450677178',
#   'type': 'CreateEvent',
#   'actor': {'id': 53900656,
#    'login': 'DariaKrasnobaeva',
#    'display_login': 'DariaKrasnobaeva',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DariaKrasnobaeva',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53900656?'},
#   'repo': {'id': 267273152,
#    'name': 'DariaKrasnobaeva/Udacity_Practical_Statistics',
#    'url': 'https://api.github.com/repos/DariaKrasnobaeva/Udacity_Practical_Statistics'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677183',
#   'type': 'CreateEvent',
#   'actor': {'id': 65067255,
#    'login': 'Muskaantawry',
#    'display_login': 'Muskaantawry',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Muskaantawry',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65067255?'},
#   'repo': {'id': 267273153,
#    'name': 'Muskaantawry/file-handling',
#    'url': 'https://api.github.com/repos/Muskaantawry/file-handling'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677184',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 34372510,
#    'login': 'Djennez',
#    'display_login': 'Djennez',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Djennez',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34372510?'},
#   'repo': {'id': 52303337,
#    'name': 'Yoast/yoastseo-amp',
#    'url': 'https://api.github.com/repos/Yoast/yoastseo-amp'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/Yoast/yoastseo-amp/issues/44',
#     'repository_url': 'https://api.github.com/repos/Yoast/yoastseo-amp',
#     'labels_url': 'https://api.github.com/repos/Yoast/yoastseo-amp/issues/44/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Yoast/yoastseo-amp/issues/44/comments',
#     'events_url': 'https://api.github.com/repos/Yoast/yoastseo-amp/issues/44/events',
#     'html_url': 'https://github.com/Yoast/yoastseo-amp/issues/44',
#     'id': 189189663,
#     'node_id': 'MDU6SXNzdWUxODkxODk2NjM=',
#     'number': 44,
#     'title': 'Header Color, Text Color, Post MetaColor fail to display as expected',
#     'user': {'login': 'Pcosta88',
#      'id': 8238074,
#      'node_id': 'MDQ6VXNlcjgyMzgwNzQ=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/8238074?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Pcosta88',
#      'html_url': 'https://github.com/Pcosta88',
#      'followers_url': 'https://api.github.com/users/Pcosta88/followers',
#      'following_url': 'https://api.github.com/users/Pcosta88/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Pcosta88/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Pcosta88/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Pcosta88/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Pcosta88/orgs',
#      'repos_url': 'https://api.github.com/users/Pcosta88/repos',
#      'events_url': 'https://api.github.com/users/Pcosta88/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Pcosta88/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 382916228,
#       'node_id': 'MDU6TGFiZWwzODI5MTYyMjg=',
#       'url': 'https://api.github.com/repos/Yoast/yoastseo-amp/labels/support',
#       'name': 'support',
#       'color': 'ededed',
#       'default': False,
#       'description': None}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2016-11-14T18:34:27Z',
#     'updated_at': '2020-05-27T09:11:32Z',
#     'closed_at': '2020-05-27T09:11:32Z',
#     'author_association': 'NONE',
#     'body': '### What did you expect to happen?\r\nWhen colors were selected for Header, Text, and PostMeta they would display.\r\n### What happened instead?\r\nThe colors did not change. \r\n### How can we reproduce this behavior?\r\n**1.Create Post**\r\n\r\n**2.Add Colors in the Glue Plugin**\r\n\r\n![screen shot 2016-11-14 at 1 33 10 pm](https://cloud.githubusercontent.com/assets/8238074/20277552/073da91a-aa6f-11e6-8371-8da84c8a0eff.png)\r\n\r\n\r\n**3.See them fail to change**\r\n\r\n![screen_shot_2016-11-14_at_1_33_25_pm](https://cloud.githubusercontent.com/assets/8238074/20277556/0ad68380-aa6f-11e6-866e-738f83b27534.png)\r\n\r\n\r\n### Technical info\r\n* WordPress version: 4.6.1\r\n* Yoast SEO version: 3.8\r\n* Yoast SEO Glue version: 0.3.3\r\n* AMP plugin version: 0.4.2\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/Yoast/yoastseo-amp/issues/comments/634533477',
#     'html_url': 'https://github.com/Yoast/yoastseo-amp/issues/44#issuecomment-634533477',
#     'issue_url': 'https://api.github.com/repos/Yoast/yoastseo-amp/issues/44',
#     'id': 634533477,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDYzNDUzMzQ3Nw==',
#     'user': {'login': 'Djennez',
#      'id': 34372510,
#      'node_id': 'MDQ6VXNlcjM0MzcyNTEw',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/34372510?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Djennez',
#      'html_url': 'https://github.com/Djennez',
#      'followers_url': 'https://api.github.com/users/Djennez/followers',
#      'following_url': 'https://api.github.com/users/Djennez/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Djennez/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Djennez/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Djennez/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Djennez/orgs',
#      'repos_url': 'https://api.github.com/users/Djennez/repos',
#      'events_url': 'https://api.github.com/users/Djennez/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Djennez/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-05-27T09:11:32Z',
#     'updated_at': '2020-05-27T09:11:32Z',
#     'author_association': 'MEMBER',
#     'body': 'The Glue for Yoast & AMP (yoastseo-amp) plugin is discontinued. Through collaboration with Google, all functionalities from this glue plugin have been implemented in the respective plugins. Please update the [AMP](https://wordpress.org/plugins/amp/) and [Yoast](https://wordpress.org/plugins/wordpress-seo/) plugins to the latest versions and remove the glue plugin.\r\n\r\nThis issue will be closed.'}},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z',
#   'org': {'id': 4690436,
#    'login': 'Yoast',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Yoast',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4690436?'}},
#  {'id': '12450677165',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 28562438,
#    'login': 'SanderHagen',
#    'display_login': 'SanderHagen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SanderHagen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28562438?'},
#   'repo': {'id': 255885092,
#    'name': 'SanderHagen/Netivity-Data-Science-Project',
#    'url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project'},
#   'payload': {'action': 'closed',
#    'number': 15,
#    'pull_request': {'url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/pulls/15',
#     'id': 423100783,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDIzMTAwNzgz',
#     'html_url': 'https://github.com/SanderHagen/Netivity-Data-Science-Project/pull/15',
#     'diff_url': 'https://github.com/SanderHagen/Netivity-Data-Science-Project/pull/15.diff',
#     'patch_url': 'https://github.com/SanderHagen/Netivity-Data-Science-Project/pull/15.patch',
#     'issue_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/issues/15',
#     'number': 15,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Add labels to the graphs',
#     'user': {'login': 'jurgenkamp',
#      'id': 62878381,
#      'node_id': 'MDQ6VXNlcjYyODc4Mzgx',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/62878381?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jurgenkamp',
#      'html_url': 'https://github.com/jurgenkamp',
#      'followers_url': 'https://api.github.com/users/jurgenkamp/followers',
#      'following_url': 'https://api.github.com/users/jurgenkamp/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jurgenkamp/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jurgenkamp/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jurgenkamp/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jurgenkamp/orgs',
#      'repos_url': 'https://api.github.com/users/jurgenkamp/repos',
#      'events_url': 'https://api.github.com/users/jurgenkamp/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jurgenkamp/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2020-05-26T09:49:49Z',
#     'updated_at': '2020-05-27T09:11:32Z',
#     'closed_at': '2020-05-27T09:11:31Z',
#     'merged_at': '2020-05-27T09:11:31Z',
#     'merge_commit_sha': '57c1def424c6ec33cbef81ef2ba7baf238294f79',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/pulls/15/commits',
#     'review_comments_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/pulls/15/comments',
#     'review_comment_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/issues/15/comments',
#     'statuses_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/statuses/a90f4276e6eee0cbd17692a17dc75d4e7cc263c4',
#     'head': {'label': 'SanderHagen:Voorspellen_lucardi_graphs',
#      'ref': 'Voorspellen_lucardi_graphs',
#      'sha': 'a90f4276e6eee0cbd17692a17dc75d4e7cc263c4',
#      'user': {'login': 'SanderHagen',
#       'id': 28562438,
#       'node_id': 'MDQ6VXNlcjI4NTYyNDM4',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/28562438?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/SanderHagen',
#       'html_url': 'https://github.com/SanderHagen',
#       'followers_url': 'https://api.github.com/users/SanderHagen/followers',
#       'following_url': 'https://api.github.com/users/SanderHagen/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/SanderHagen/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/SanderHagen/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/SanderHagen/subscriptions',
#       'organizations_url': 'https://api.github.com/users/SanderHagen/orgs',
#       'repos_url': 'https://api.github.com/users/SanderHagen/repos',
#       'events_url': 'https://api.github.com/users/SanderHagen/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/SanderHagen/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 255885092,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNTU4ODUwOTI=',
#       'name': 'Netivity-Data-Science-Project',
#       'full_name': 'SanderHagen/Netivity-Data-Science-Project',
#       'private': False,
#       'owner': {'login': 'SanderHagen',
#        'id': 28562438,
#        'node_id': 'MDQ6VXNlcjI4NTYyNDM4',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/28562438?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/SanderHagen',
#        'html_url': 'https://github.com/SanderHagen',
#        'followers_url': 'https://api.github.com/users/SanderHagen/followers',
#        'following_url': 'https://api.github.com/users/SanderHagen/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/SanderHagen/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/SanderHagen/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/SanderHagen/subscriptions',
#        'organizations_url': 'https://api.github.com/users/SanderHagen/orgs',
#        'repos_url': 'https://api.github.com/users/SanderHagen/repos',
#        'events_url': 'https://api.github.com/users/SanderHagen/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/SanderHagen/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/SanderHagen/Netivity-Data-Science-Project',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project',
#       'forks_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/forks',
#       'keys_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/teams',
#       'hooks_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/hooks',
#       'issue_events_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/events',
#       'assignees_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/tags',
#       'blobs_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/languages',
#       'stargazers_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/stargazers',
#       'contributors_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/contributors',
#       'subscribers_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/subscribers',
#       'subscription_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/subscription',
#       'commits_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/merges',
#       'archive_url': 'https://api.github.com/repos/SanderHagen/Netivity-Data-Science-Project/{archive_format}{/ref}',
# ...
#      'received_events_url': 'https://api.github.com/users/kelson42/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'kelson42',
#       'id': 1029718,
#       'node_id': 'MDQ6VXNlcjEwMjk3MTg=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/1029718?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kelson42',
#       'html_url': 'https://github.com/kelson42',
#       'followers_url': 'https://api.github.com/users/kelson42/followers',
#       'following_url': 'https://api.github.com/users/kelson42/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kelson42/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kelson42/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kelson42/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kelson42/orgs',
#       'repos_url': 'https://api.github.com/users/kelson42/repos',
#       'events_url': 'https://api.github.com/users/kelson42/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kelson42/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-05-27T09:11:32Z',
#     'updated_at': '2020-05-27T09:11:32Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': '*Please use the following format for a ZIM creation request…*\r\n\r\n- Website URL: https://dicoado.org/\r\n- License: ** CC-by-sa 4.0**\r\n- Desired ZIM Title: **Le Dico des Ados**\r\n- Desired ZIM Description: ** Le Dico des Ados, ton dictionnaire collaboratif, libre et gratuit ! **\r\n- Desired ZIM Icon –png (URL or attach one): https://commons.m.wikimedia.org/wiki/File:Le_Dico_des_Ados_small_logo.png#/media/File%3ALe_Dico_des_Ados_small_logo.svg\r\n- Language (ISO 639-3): **eng**\r\n- Desired Main Page (homepage): **n/a**\r\n- Is this a MediaWiki?: **yes**\r\n- Articles List URL (mediawiki): **n/a**\r\n'}},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z',
#   'org': {'id': 26540839,
#    'login': 'openzim',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/openzim',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26540839?'}},
#  {'id': '12450677159',
#   'type': 'PublicEvent',
#   'actor': {'id': 51945911,
#    'login': 'afittestide',
#    'display_login': 'afittestide',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/afittestide',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51945911?'},
#   'repo': {'id': 256925027,
#    'name': 'afittestide/terminal7',
#    'url': 'https://api.github.com/repos/afittestide/terminal7'},
#   'payload': {},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z',
#   'org': {'id': 51945911,
#    'login': 'afittestide',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/afittestide',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51945911?'}},
#  {'id': '12450677153',
#   'type': 'CreateEvent',
#   'actor': {'id': 61238332,
#    'login': 'bguillaume0',
#    'display_login': 'bguillaume0',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bguillaume0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61238332?'},
#   'repo': {'id': 267273121,
#    'name': 'bguillaume0/rails-yelp-mvp',
#    'url': 'https://api.github.com/repos/bguillaume0/rails-yelp-mvp'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677143',
#   'type': 'PushEvent',
#   'actor': {'id': 33904310,
#    'login': 'ThomasKeralla',
#    'display_login': 'ThomasKeralla',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ThomasKeralla',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33904310?'},
#   'repo': {'id': 243014651,
#    'name': 'zanderhavgaard/faas-benchmarker',
#    'url': 'https://api.github.com/repos/zanderhavgaard/faas-benchmarker'},
#   'payload': {'push_id': 5134550310,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/track-cl_funtions-lifecycle',
#    'head': 'b1f3ea2498160214391beab8a6564df219f0ed31',
#    'before': '29bbb5fd4ec433da272deb9f847410b011c075f6',
#    'commits': [{'sha': 'b1f3ea2498160214391beab8a6564df219f0ed31',
#      'author': {'email': 'thomas@localhost.localdomain', 'name': 'Thomas'},
#      'message': 'small adjustments to weakest link experiment',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zanderhavgaard/faas-benchmarker/commits/b1f3ea2498160214391beab8a6564df219f0ed31'}]},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677134',
#   'type': 'PushEvent',
#   'actor': {'id': 6744395,
#    'login': 'hughex',
#    'display_login': 'hughex',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hughex',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6744395?'},
#   'repo': {'id': 156638192,
#    'name': 'FutunnOpen/py-futu-api',
#    'url': 'https://api.github.com/repos/FutunnOpen/py-futu-api'},
#   'payload': {'push_id': 5134550308,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/v3.22',
#    'head': '3d50672fb118e26a4c8417f839dd017a4ede46e3',
#    'before': '93a899e243a6f1753648367410d592ec03ac5827',
#    'commits': [{'sha': '3d50672fb118e26a4c8417f839dd017a4ede46e3',
#      'author': {'email': 'hugh@futunn.com', 'name': 'hugh'},
#      'message': '更新协议',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/FutunnOpen/py-futu-api/commits/3d50672fb118e26a4c8417f839dd017a4ede46e3'}]},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677129',
#   'type': 'PushEvent',
#   'actor': {'id': 26174424,
#    'login': 'nakulnagariy',
#    'display_login': 'nakulnagariy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nakulnagariy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26174424?'},
#   'repo': {'id': 267033279,
#    'name': 'nakulnagariy/task-manager-api',
#    'url': 'https://api.github.com/repos/nakulnagariy/task-manager-api'},
#   'payload': {'push_id': 5134550298,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c2a0d75a9e606af7916ac759459a2a7d920cc0b0',
#    'before': '9d42b02cc868e272050065ca59369700648eaf05',
#    'commits': [{'sha': 'c2a0d75a9e606af7916ac759459a2a7d920cc0b0',
#      'author': {'email': 'nagariya23nakul@gmail.com', 'name': 'Nacool'},
#      'message': 'added body parser',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nakulnagariy/task-manager-api/commits/c2a0d75a9e606af7916ac759459a2a7d920cc0b0'}]},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677122',
#   'type': 'PushEvent',
#   'actor': {'id': 50001808,
#    'login': 'tiepdotme',
#    'display_login': 'tiepdotme',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tiepdotme',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50001808?'},
#   'repo': {'id': 237870289,
#    'name': 'tiepdotme/callum-flack-design',
#    'url': 'https://api.github.com/repos/tiepdotme/callum-flack-design'},
#   'payload': {'push_id': 5134550293,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3cf5e15b63d4db0110adf4f65f8c4d7046450b97',
#    'before': '958711b9ad615fce59275d69724b6accb0823d2b',
#    'commits': [{'sha': '3cf5e15b63d4db0110adf4f65f8c4d7046450b97',
#      'author': {'email': '50001808+tiepdotme@users.noreply.github.com',
#       'name': 'Tiep'},
#      'message': 'Create gushop-vnxk-theme-redesign.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tiepdotme/callum-flack-design/commits/3cf5e15b63d4db0110adf4f65f8c4d7046450b97'}]},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677127',
#   'type': 'IssuesEvent',
#   'actor': {'id': 353346,
#    'login': 'bestchai',
#    'display_login': 'bestchai',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bestchai',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/353346?'},
#   'repo': {'id': 266978432,
#    'name': 'ModelInference/perfume-frontend',
#    'url': 'https://api.github.com/repos/ModelInference/perfume-frontend'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/ModelInference/perfume-frontend/issues/47',
#     'repository_url': 'https://api.github.com/repos/ModelInference/perfume-frontend',
#     'labels_url': 'https://api.github.com/repos/ModelInference/perfume-frontend/issues/47/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ModelInference/perfume-frontend/issues/47/comments',
#     'events_url': 'https://api.github.com/repos/ModelInference/perfume-frontend/issues/47/events',
#     'html_url': 'https://github.com/ModelInference/perfume-frontend/issues/47',
#     'id': 625521021,
#     'node_id': 'MDU6SXNzdWU2MjU1MjEwMjE=',
#     'number': 47,
#     'title': 'Remove link to tutorial/example',
#     'user': {'login': 'bestchai',
#      'id': 353346,
#      'node_id': 'MDQ6VXNlcjM1MzM0Ng==',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/353346?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/bestchai',
#      'html_url': 'https://github.com/bestchai',
#      'followers_url': 'https://api.github.com/users/bestchai/followers',
#      'following_url': 'https://api.github.com/users/bestchai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/bestchai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/bestchai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/bestchai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/bestchai/orgs',
#      'repos_url': 'https://api.github.com/users/bestchai/repos',
#      'events_url': 'https://api.github.com/users/bestchai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/bestchai/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-05-27T09:11:31Z',
#     'updated_at': '2020-05-27T09:11:32Z',
#     'closed_at': '2020-05-27T09:11:32Z',
#     'author_association': 'MEMBER',
#     'body': 'These links are currently inactive. We should remove these from the interface and instead concentrate on the other tabs.'}},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z',
#   'org': {'id': 12242425,
#    'login': 'ModelInference',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ModelInference',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12242425?'}},
#  {'id': '12450677103',
#   'type': 'PushEvent',
#   'actor': {'id': 17243442,
#    'login': 'thanhnguyennguyen',
#    'display_login': 'thanhnguyennguyen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/thanhnguyennguyen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17243442?'},
#   'repo': {'id': 221151068,
#    'name': 'thanhnguyennguyen/tomochain',
#    'url': 'https://api.github.com/repos/thanhnguyennguyen/tomochain'},
#   'payload': {'push_id': 5134550288,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/update-default-tomox-datadir',
#    'head': 'dc7b14e6ca512321f49098e4cfc99425aa8fd4a3',
#    'before': '8ccb592141bae47836ae386d404edf36f9486eab',
#    'commits': [{'sha': 'dc7b14e6ca512321f49098e4cfc99425aa8fd4a3',
#      'author': {'email': 'nguyenbk92@gmail.com', 'name': 'NguyenNguyen'},
#      'message': 'setting tomoxdatadir following datadir at the runtime',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/thanhnguyennguyen/tomochain/commits/dc7b14e6ca512321f49098e4cfc99425aa8fd4a3'}]},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677121',
#   'type': 'CreateEvent',
#   'actor': {'id': 34971977,
#    'login': 'tudormd',
#    'display_login': 'tudormd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tudormd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34971977?'},
#   'repo': {'id': 262311178,
#    'name': 'goparrot/chowly-api-client',
#    'url': 'https://api.github.com/repos/goparrot/chowly-api-client'},
#   'payload': {'ref': 'hotfix/2248-add-required-id-order',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z',
#   'org': {'id': 47812435,
#    'login': 'goparrot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/goparrot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47812435?'}},
#  {'id': '12450677112',
#   'type': 'WatchEvent',
#   'actor': {'id': 1493360,
#    'login': 'kevin7lou',
#    'display_login': 'kevin7lou',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kevin7lou',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1493360?'},
#   'repo': {'id': 183742673,
#    'name': 'NJUPTFreeExams/NJUPT-Managing-Free-Exams',
#    'url': 'https://api.github.com/repos/NJUPTFreeExams/NJUPT-Managing-Free-Exams'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z',
#   'org': {'id': 46742360,
#    'login': 'NJUPTFreeExams',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/NJUPTFreeExams',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46742360?'}},
#  {'id': '12450677106',
#   'type': 'PushEvent',
#   'actor': {'id': 64413136,
#    'login': 'Sailaja6',
#    'display_login': 'Sailaja6',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Sailaja6',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64413136?'},
#   'repo': {'id': 264800801,
#    'name': 'Sailaja6/ADF_Demo1',
#    'url': 'https://api.github.com/repos/Sailaja6/ADF_Demo1'},
#   'payload': {'push_id': 5134550279,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feature2',
#    'head': 'dbac4f0da3d9a6083a5c061648a74187aaef4c24',
#    'before': '74eb65b95fea0bad8a4ccab199c274d851f9cd82',
#    'commits': [{'sha': 'dbac4f0da3d9a6083a5c061648a74187aaef4c24',
#      'author': {'email': '64413136+Sailaja6@users.noreply.github.com',
#       'name': 'Sailaja6'},
#      'message': 'Deleting pipeline: SalesKPI',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Sailaja6/ADF_Demo1/commits/dbac4f0da3d9a6083a5c061648a74187aaef4c24'}]},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677097',
#   'type': 'PushEvent',
#   'actor': {'id': 66003197,
#    'login': 'richie1221',
#    'display_login': 'richie1221',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/richie1221',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66003197?'},
#   'repo': {'id': 267257774,
#    'name': 'richie1221/linux_test',
#    'url': 'https://api.github.com/repos/richie1221/linux_test'},
#   'payload': {'push_id': 5134550280,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c0e3aa1c9f36c06aecf8a3965e2128fd47500f37',
#    'before': '76b892d7b676c7449465af53e041bce4c78eac37',
#    'commits': [{'sha': 'c0e3aa1c9f36c06aecf8a3965e2128fd47500f37',
#      'author': {'email': 'richie89147@gmail.com', 'name': 'richie1221'},
#      'message': '5',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/richie1221/linux_test/commits/c0e3aa1c9f36c06aecf8a3965e2128fd47500f37'}]},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'},
#  {'id': '12450677090',
#   'type': 'CreateEvent',
#   'actor': {'id': 1541701,
#    'login': 'julioz',
#    'display_login': 'julioz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/julioz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1541701?'},
#   'repo': {'id': 252514550,
#    'name': 'julioz/FloorPlan',
#    'url': 'https://api.github.com/repos/julioz/FloorPlan'},
#   'payload': {'ref': 'output-format-def',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Translate Room schemas to DBML',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-27T09:11:32Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests, json

r = requests.get("https://cat-fact.herokuapp.com/facts")
json.loads(r.text)
# Out:
# {'all': [{'_id': '5887e1d85c873e0011036889',
#    'text': 'Cats make about 100 different sounds. Dogs make only about 10.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 10,
#    'userUpvoted': None},
#   {'_id': '58e00b450aac31001185ed21',
#    'text': "There are 45 Hemingway cats living at the author's former home in Key West, Fla.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 9,
#    'userUpvoted': None},
#   {'_id': '58e008b80aac31001185ed0d',
#    'text': 'Adult cats only meow to communicate with humans.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 9,
#    'userUpvoted': None},
#   {'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 8,
#    'userUpvoted': None},
#   {'_id': '58e00b970aac31001185edf9',
#    'text': 'A house cat is faster than Usain Bolt.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 8,
#    'userUpvoted': None},
#   {'_id': '58e009650aac31001185ed13',
#    'text': 'In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '58e00af60aac31001185ed1d',
#    'text': 'It was illegal to slay cats in ancient Egypt, in large part because they provided the great service of controlling the rat population.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '5e236d6bdc76630015d4c51f',
#    'type': 'cat',
#    'text': 'gato loves grace',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '59a60b8e6acf530020f3586e',
#    'text': 'Cat owners are 17% more likely to have a graduate degree than non cat owners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '58e009550aac31001185ed12',
#    'text': 'The oldest cat video on YouTube dates back to 1894.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e008340aac31001185ecfb',
#    'text': 'Cats sleep 70% of their lives.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '599f87db9a11040c4a16343f',
#    'text': 'The goddess of love, beauty, and fertility in Norse mythology, Freyja was the first cat lady. She is depicted in stories as riding a chariot that was drawn by cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5894af975cdc7400113ef7f9',
#    'text': 'The technical term for a cat’s hairball is a bezoar.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b0c5e3e7ab3c50014df65fe',
#    'text': 'People who own cats have on average 2.1 pets per household, where dog owners have about 1.6.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e00a000aac31001185ed15',
#    'text': 'Female cats are typically right-pawed while male cats are typically left-pawed.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e00a1a0aac31001185ed18',
#    'text': 'Cats and humans have nearly identical sections of the brain that control emotion.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e0088b0aac31001185ed09',
#    'text': "The world's largest cat measured 48.5 inches long.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00a7e0aac31001185ed19',
#    'text': "A cat's cerebral cortex (the part of the brain in charge of cognitive information processing) has 300 million neurons, compared with a dog's 160 million.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00b1f0aac31001185ed1e',
#    'text': 'In the 15th century, Pope Innocent VIII began ordering the killing of cats, pronouncing them demonic.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58f89cff11658e00113ddd26',
#    'text': 'Cats love to eat olives or for that matter anything preserved in brine.',
#    'type': 'cat',
#    'user': {'_id': '58f89c8d11658e00113ddd24',
#     'name': {'first': 'Malvika', 'last': 'Tewari'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5955792c7b77520020799431',
#    'text': 'Cats "knead" because of seperation from their mothers',
#    'type': 'cat',
#    'user': {'_id': '595579027b77520020799430',
#     'name': {'first': 'Is It Still Memes That', 'last': 'Make You Sweat?'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a090aac31001185ed16',
#    'text': 'Cats make more than 100 different sounds whereas dogs make around 10.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c489117e4f6130014c987b9',
#    'text': 'Leonardo da Vinci created a series of drawings titled "Study of Cat Movements and Positions", which consists of more than twenty drawings of cats and lions lying a sleep, sitting, playing, and fighting.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60982ce549020014533033',
#    'text': 'The Chartreux is distinguished by a woolly blue-grey coat, a robust body poised over small paws, and full cheeks with a mouth that always appear to be smiling.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609852e549020014533036',
#    'text': "While Chartreux cats aren't very vocal, they are sociable and communicate through eye contact and body language.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60999ae549020014533038',
#    'text': 'Cats love playing with yarn, ribbons, and fishing-rode style toys. However, cats should not be left alone with anything that they could get tangled in.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a02e549020014533039',
#    'text': "All Scottish Folds descended from Susie, a white barn cat discovered in Scotland in the early 1960s. Susie sported the breed's folded ears – the result of a genetic mutation – and passed on the trait through breeding.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a90e54902001453303a',
#    'text': 'Mark Twain was undeniably an ailurophile. He had up to 19 cats at one time and gave them such memorable names as Beelzebub, Buffalo Bill, and Soapy Sal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c35cc2d7a200140f67ea',
#    'text': 'If you really want to treat your cat, get some lactose-free milk at the grocery store and offer some to the kitty.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c47dc2d7a200140f67ee',
#    'text': 'Abraham Lincoln, being the ailurophile that he was, once rescued three stray kittens and ensured that they were fed and found homes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c4eec2d7a200140f67ef',
#    'text': 'The Sphynx was originally known as the Canadian Hairless Cat. The breed originated in Toronto, and was renamed to Sphynx, a nod to the famous limestone sculpture in the Egyptian Desert.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c6a104fc2d7a200140f699f',
#    'text': 'A cat’s spine can rotate more than the spines of most other animals, and their vertebrae have a special, flexible, elastic cushioning on the disks, which gives it even more flexibility.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72d9b651021f001415f00c',
# ...
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609945e549020014533037',
#    'text': 'Do you ever wake up in the middle of the night and find your cat sleeping on your head? Cat behavioral experts believe that cats are drawn to the warmth and the familiar scent of the owner. Resting on your head also keeps kitty safe from your arms and legs if you toss and turn through the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c7408a14dd87d001490f02b',
#    'text': "The cheetah is the only cat that doesn't have retractable claws.",
#    'type': 'cat',
#    'user': {'_id': '5c72e94751021f001415f012',
#     'name': {'first': 'Tests', 'last': 'HiQ'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c75f56272681400147b988a',
#    'text': 'There are only two escalators in the state of Wyoming.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c84248f731a60001540a193',
#    'text': 'When a cat lifts its butt in the air when scratched, it is a sign that your feline is giving your pats an A+. However, if you have a female kitty who hasn\'t been spayed, "elevator butt" could be a sign that she\'s ready to mate. The proper name for this stance is lordosis, and cats adopt it when they\'re in heat.',
#    'type': 'cat',
#    'user': {'_id': '5c7da4bd70008708fb17c88f',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c87d03dec1e5c0aa37e0a6b',
#    'type': 'cat',
#    'text': 'On October 24, 1963, a tuxedo cat named Félicette entered outer space aboard a French Véronique AG1 rocket and made feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to 14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e83ff18f53272001515690c',
#    'type': 'cat',
#    'text': 'Cats are capable of walking very precisely because, like all felines, they directly register; that is, they place each hind paw (almost) directly in the print of the corresponding fore paw, minimizing noise and visible tracks. This also provides sure footing for their hind paws when they navigate rough terrain.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e10d7841c78ab0015bc5b15',
#    'type': 'cat',
#    'text': 'Some cats do not eat fish.',
#    'user': {'_id': '5e10d6e51c78ab0015bc5b14',
#     'name': {'first': 'Max', 'last': 'Bilohatnyuk'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e80e7cc2d4b850015003072',
#    'type': 'cat',
#    'text': 'Cats can climb on trees faster than squirels.',
#    'user': {'_id': '5e80e6c72d4b85001500306e',
#     'name': {'first': 'Łukasz', 'last': 'Wiktorko'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e19da391fd6150015fa7356',
#    'type': 'cat',
#    'text': '"Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.".',
#    'user': {'_id': '5e19d99e1fd6150015fa7353',
#     'name': {'first': 'Crystal Gale', 'last': 'Scott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e1efba858449a0015ce4783',
#    'type': 'cat',
#    'text': '"A house cat is faster than Usain Bolt.".',
#    'user': {'_id': '5e1efb5958449a0015ce4781',
#     'name': {'first': 'oyaji', 'last': '55'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eafdaf354ad960017b3703d',
#    'type': 'cat',
#    'text': 'Yjyyu.',
#    'user': {'_id': '5eafdad954ad960017b37038',
#     'name': {'first': 'Lulu', 'last': 'Dauphin'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ebbf5dd8046d00017776020',
#    'type': 'cat',
#    'text': 'Cats are fat, sometimes.',
#    'user': {'_id': '5ebbf5cd8046d0001777601f',
#     'name': {'first': 'George', 'last': 'Miguel'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ec4aad30c796a00174d7b26',
#    'type': 'cat',
#    'text': 'Sss.',
#    'user': {'_id': '5ec4a7d60c796a00174d7b25',
#     'name': {'first': 'Minh', 'last': 'Nguyễn'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ec93d1de11bba0017c67e19',
#    'type': 'cat',
#    'text': 'In a sense, cats can see in the dark.',
#    'user': {'_id': '5ec93c89e11bba0017c67e18',
#     'name': {'first': 'Mandy', 'last': 'c'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecb032ab0d92c0017cab214',
#    'type': 'cat',
#    'text': 'Cats are the best pets.',
#    'user': {'_id': '5ecb02e4b0d92c0017cab213',
#     'name': {'first': 'Victor Manuel', 'last': 'Díaz de La Gasca'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecb0333b0d92c0017cab215',
#    'type': 'cat',
#    'text': 'Hello cats.',
#    'user': {'_id': '5ecb02e4b0d92c0017cab213',
#     'name': {'first': 'Victor Manuel', 'last': 'Díaz de La Gasca'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecdda946253f20017f53ec5',
#    'type': 'cat',
#    'text': 'Cats love womans, dog loves mans.',
#    'user': {'_id': '5ecdda686253f20017f53ec4',
#     'name': {'first': 'Jorge Alberto', 'last': 'Gil Rendon'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ea7496761cd4d0017498a94',
#    'type': 'cat',
#    'text': 'Ancient sailors believed that cats were magic and would often risk their own lives, even in an "every man for himself" situation, to save a cat from a sinking ship. All ships had at least one ship\'s cat as cats would eat the rats that have always plagued ships. The ship\'s cat would often be given a rank and sailors would generally take excessively good care of their cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eaafca69105ce00177573de',
#    'type': 'cat',
#    'text': 'Cats sleep most of the time.',
#    'user': {'_id': '5ea977d1cd53d20017d7d8b2',
#     'name': {'first': 'Quang', 'last': 'Pham'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}
